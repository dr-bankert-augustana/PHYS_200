# %% [markdown]
# <a href="https://colab.research.google.com/github/dr-bankert-augustana/PHYS_200/blob/main/PAL_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a name="Notebook-Start"></a>
#
# ---
#
# <font size = 7> <b> PAL (Pandas Introduction) </b> </font>
#
# ---

# %% [markdown]
# Although this dataset is about restaurant tips, the skills you’re learning apply directly to physics. Whether you're analyzing sensor data, experimental results, or simulations, you'll often work with tabular data like this. Today, we're using a simple, fun dataset to focus purely on learning the toolset.

# %% [markdown]
# <a name="Problem 1"></a>
#
# ---
#
# <font size = 6> <b> Problem 1: Load and Investigate the Data </b> </font>
#
# ---

# %% [markdown]
# * Import the pandas and seaborn libraries.
#
# * Use this code to load the data: <code>tips = sns.load_dataset('tips')</code>

# %% [markdown]
# <b>Question 1:</b> What are the columns in this dataset? What do you think each one represents?
#
# <br>
#
# <b>Question 2:</b> How many entries are in the dataset? Are all columns numeric? Which ones are categorical?
#
# <br>
#
# <b>Question 3:</b> What are the mean, min, and max values for total_bill and tip? How might this relate to the concept of distributions in experimental data?

# %% [markdown]
# <a name="Problem 2"></a>
#
# ---
#
# <font size = 6> <b> Problem 2: Basic Analysis and Filtering</b> </font>
#
# ---

# %% [markdown]
# <b>Question 4:</b> What is the average tip amount for each day of the week.
#
# <br>
#
# <b>Question 5:</b> Which day has the highest average tip? Could this be analogous to measuring peak activity in an experiment?
#
# <br>
#
# <b>Question 6:</b> Create a new column: tip percentage, why might this type of column be useful?
#
# <br>
#
# <b>Question 7:</b> Filter the dataset to include only parties of size 4 or more.
# How does the average tip percentage for large parties compare to the whole dataset?
