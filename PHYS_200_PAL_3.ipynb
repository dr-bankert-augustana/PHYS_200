# %% [markdown]
# <a href="https://colab.research.google.com/github/dr-bankert-augustana/PHYS_200/blob/main/PHYS_200_PAL_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a name="Notebook-Start"></a>
#
# ---
#
# <font size = 7> <b> PAL (Pandas Continued) </b> </font>
#
# ---

# %% [markdown]
# In this activity, we will be using a dataset of measurements collected on a set of penguins of various species.

# %%
# Import seaborn library:

import seaborn as sns

# Load the penguins dataset:

penguins_df = sns.load_dataset("penguins")

# %% [markdown]
# <a name="Problem-1"></a>
#
# ---
#
# <font size = 6> <b> Problem 1: Investigate the Data </b> </font>
#
# ---

# %% [markdown]
# <b>Question 1:</b> What are the columns in this dataset? What do you think each one represents?
#
# <br>
#
# <b>Question 2:</b> How many entries are in the dataset? Are all columns numeric? Which ones are categorical?
#
# <br>
#
# <b>Question 3:</b> What are the mean, min, and max values for the numeric columns?

# %% [markdown]
# <a name="Problem-2:"></a>
#
# ---
#
# <font size = 6> <b> Problem 2: Data Filtering </b> </font>
#
# ---

# %% [markdown]
# <b>Question 1:</b> Use query() to filter penguins by island. Create a new DataFrame for each island.
#
# <br>
#
# <b>Question 2:</b> Use query() to filter penguins by species. Create a new DataFrame for each species.
#
# <br>
#
# <b>Question 3:</b> Use query() to create a DataFrame with only Gentoo penguins from Biscoe island.

# %% [markdown]
# <a name="Problem-3:"></a>
#
# ---
#
# <font size = 6> <b> Problem 3: Group Analysis </b> </font>
#
# ---

# %% [markdown]
# <b>Question 1:</b> Use groupby() to get the average flipper length of penguins for each species.
#
# <br>
#
# <b>Question 2:</b> Use groupby() to get the average bill length of penguins for each island.
#
# <br>
#
# <b>Question 3:</b> Use groupby() to find the smallest (in mass) penguin for each island.
#
# <br>
#
# <b>Question 4:</b> Use groupby() to find the largest (in mass) penguin for each species.

# %% [markdown]
# <a name="Problem-4:"></a>
#
# ---
#
# <font size = 6> <b> Problem 4: Correlation </b> </font>
#
# ---

# %% [markdown]
# <b>Question 1:</b> What is the correlation coefficient for bill size and body size for all penguins?
#
# <br>
#
# <b>Question 2:</b> What is the correlation coefficient for flipper length and bill depth for all penguins?
#
# <br>
#
# <b>Question 3:</b> How do these values change when we confine our analysis to only Adiele penguins?

# %% [markdown]
# <a name="Problem-4:"></a>
#
# ---
#
# <font size = 6> <b> Problem 5: Plotting </b> </font>
#
# ---

# %% [markdown]
# <b>Question 1:</b> Create a variety of types plots using this data set for all penguins.
#
# <br>
#
# <b>Question 2:</b> Create the same plots, but confine your dataset to a single species of penguins and see how the results change.
#
# <br>
#
# <b>Question 3:</b> Describe the physical significance of the plots you chose to make and why you thought they would be interesting.
