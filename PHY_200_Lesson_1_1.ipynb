# %% [markdown]
# <a href="https://colab.research.google.com/github/dr-bankert-augustana/PHYS_200/blob/main/PHY_200_Lesson_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a name="Notebook-Start"></a>
#
# ---
#
# <font size = 7> <b> Lesson 1.1 (Introduction to Python) </b> </font>
#
# ---

# %% [markdown]
# <font size = 5> <b> Notebook Index </b> </font>
#
# 1.  [Learning Outcomes](#Learning-Outcomes)
#
# 2.  [Introduction](#Introduction)
#
# 3.  [Import Python Libraries](#Import-Python-Libraries)
#
# 4.  [Define Useful Functions](#Define-Useful-Functions)
#
# 5.  [Load The Dataset](#Load-The-Dataset)
#
# 6.  [Investigation: Explore The Data](#Investigation)
#
# 7.  [Abstraction: Develop A Model](#Abstraction)
#
# 8.  [Implementation: Trying Specific Models](#Implementation)
#
# 9.  [Validation: Introducing Error and Loss Functions](#Validation)
#
# 10. [Iteration: Improving the Model](#Iteration)
#
# 11. [Interpretation: Gaining Physical Understanding](#Interpretation)
#
# 12. [Lesson Summary](#Lesson-Summary)
#
# 13. [Appendix A: New Term Definitions](#Appendix-Definitions)
# $
# \newcommand{\lsum}{\displaystyle \sum\limits_{i=1}^{N}}
# \newcommand{\parens}[1]{\left(#1\right)}
# \newcommand{\dsfrac}[2]{\displaystyle\frac{#1}{#2}}
# \newcommand{\dpfrac}[2]{\displaystyle\parens{\frac{#1}{#2}}}
# \newcommand{\parderiv}[2]{\dsfrac{\partial #1}{\partial #2}}
# \newcommand{\spc}{\hspace{0.1 pc}}
# \newcommand{\ra}{\Rightarrow}
# \newcommand{\of}[1]{{\scriptsize (#1)}}
# \newcommand{\rule}{\Huge \hspace{-0.2 pc} \displaystyle\frac{\hspace{20 pc}}{\hspace{20 pc}}}
# \newcommand{\mps}{\spc \frac{\textrm{m}}{\textrm{s}}}
# \newcommand{\mpss}{\spc \frac{\textrm{m}}{\textrm{s}^2}}
# $

# %% [markdown]
# <a name="Learning-Outcomes"></a>
#
# ---
#
# <font size = 6> <b> 1. Learning Outcomes </b> </font>
#
# ---

# %% [markdown]
# stuff

# %% [markdown]
# [Return to Top](#Notebook-Start)

# %% [markdown]
# <a name="Introduction"></a>
#
# ---
#
# <font size = 6> <b> 2. Introduction </b> </font>
#
# ---

# %% [markdown]
# # <center> Welcome to Python and Jupyter Notebooks </center>
#
# <div style="text-align: justify">
#     Python is an extremely versatile and powerful programming language that is
#     also very user friendly (compared to some other languages). Jupyter
#     Notebooks is an education and presentation tool that takes the power of
#     Python and incorporates a "cell-based" infrastructure that allows a program
#     to be broken up into small code "chunks" so they can be analyzed and
#     presented. For example, what you are reading right now is called a
#     "Markdown" cell. Here a user can write descriptions or commentary about the
#     program. The cell below this is called a "Code" cell. It will contain actual
#     Python code, which can be run just like a real program.
# </div>

# %%
# This is a code comment, when you want to write in a Code cell without altering the code itself, you need to make
# a comment by putting a "pound sign" (or "hash-tag") in front of the line you want to commment out. In this cell,
# we are asking the program to print out the phrase "Hello World". The output of the print command will appear
# below the Code cell. We can execute a Code cell by selecting it and pressing the Play button at the top of the
# Jupyter Notebook window.

print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Your Turn!
#
# <div style="text-align: justify">
# In the following Code cell, type: print("Hello Jupyter Notebooks!"). Then, with the Code cell selected, press the Play button at the top of the Jupyter Notebook window.
# </div>

# %% [markdown]
# [Return to Top](#Notebook-Start)
