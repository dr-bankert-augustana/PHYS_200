# %% [markdown]
# <a href="https://colab.research.google.com/github/dr-bankert-augustana/PHYS_200/blob/main/Projects/Final_Project/Final_Project_Overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a name="Notebook-Start"></a>
#
# ---
#
# <font size = 7> <b> Computational Physics Final Project: Proposal Assignment </b> </font>
#
# ---

# %% [markdown]
# <font size = 5> <b> Overview </b> </font>
#
# Your PHYS 200 final project is an opportunity to apply the data analysis and computational modeling techniques you have learned in this course to a real-world physical system of your choosing.
#
# <br>
#
# <b>You must work in a group with one other student.</b>
#
# <br>
#
# <b>Final Project Goals:</b>
#
# 1. Choose (or create) and analyze a real-world data set
#
# 2. Identify and explain the underlying physical principles governing the system
#
# 3. Develop a physics-based computational model of those principles
#
# 4. Compare your simulation results to real-world data
#
# 5. Iteratively refine your model to improve agreement and understanding
#
# <br>
#
# <b>Final Project Steps:</b>
#
# 1. Brainstorm (or search out) possible sources of real-world data
#
#    * <b>You must obtain instructor approval to proceed from this point</b>
#
# 2. Write and submit a project proposal (details to follow on Thursday)
#
#    * <b>You must obtain instructor approval to proceed from this point</b>
#
# 3. Obtain (or generate) real-world data for your approved project
#
# 4. Analyze your data to:
#
#    * Identify trends and patterns
#    * Determine relevant physical relationships
#    * Estimate key physical parameters
#
# 5. In Colab, develop a simulation of your system that generates synthetic data
#
#    * Start with a simple baseline model (layer on complexity later)
#    * Clearly state assumptions
#    * Use computational modeling methods from class
#
# 6. Compare your simulation output to real-world data
#
#    * Create meaningful plots
#    * Identify and justify useful comparison metrics
#    * Identify where and why the model succeeds or fails
# 7. Iteratively refine your model
#
#    * You must implement at least <b>3 substantial revisions</b>
#    * Each revision must be clearly documented, including:
#      - What was changed
#      - Why it was changed
#      - How it affected agreement with data
#
# 8. Produce a final, polished write-up of your project (details to follow next week) that includes:
#
#    * Data analysis
#    * Model development
#    * Comparison to real data
#    * Iteration process
#    * Final conclusions
#
# 9. Prepare a presentation for the class (15 minutes)
